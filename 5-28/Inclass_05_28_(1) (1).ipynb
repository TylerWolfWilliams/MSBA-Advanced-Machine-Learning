# %% [markdown]
# # Day 2 RNN

# %% [markdown]
# ### Importing libraries

# %%
# Libraries

import random

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, SimpleRNN, LSTM, GRU
from tensorflow.keras.callbacks import EarlyStopping

random.seed(42)
np.random.seed(42)
tf.random.set_seed(42)

# %% [markdown]
# ### Load & inspect data

# %%
# Load and inspect Bitcoin data

bitcoin = pd.read_csv("dc.csv")

bitcoin = bitcoin.rename(
    columns={"Unnamed: 0": "date"}
)

bitcoin["date"] = pd.to_datetime(bitcoin["date"])

bitcoin = (
    bitcoin
    .sort_values("date")
    .reset_index(drop=True)
)

print(bitcoin.shape)

bitcoin.head()
# Out:
# (1000, 6)
#         date  open_USD  high_USD  low_USD  close_USD  volume
# 0 2018-05-07   9661.02   9689.67  9181.00    9365.00   33787
# 1 2018-05-08   9365.00   9475.70  9060.54    9187.56   25533
# 2 2018-05-09   9178.00   9390.00  8965.00    9310.00   25673
# 3 2018-05-10   9310.00   9395.12  8970.00    9002.20   25055
# 4 2018-05-11   9002.21   9016.80  8341.00    8400.00   48227

# %%
# Basic inspection

bitcoin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       1000 non-null   datetime64[ns]
#  1   open_USD   1000 non-null   float64
#  2   high_USD   1000 non-null   float64
#  3   low_USD    1000 non-null   float64
#  4   close_USD  1000 non-null   float64
#  5   volume     1000 non-null   int64
# dtypes: datetime64[ns](1), float64(4), int64(1)
# memory usage: 47.0 KB

# %%
# Summary statistics

bitcoin.describe()
# Out:
#                       date      open_USD      high_USD       low_USD  \
# count                 1000   1000.000000   1000.000000   1000.000000
# mean   2019-09-18 12:00:00   9285.762120   9542.880270   9011.393200
# min    2018-05-07 00:00:00   3211.710000   3276.500000   3156.260000
# 25%    2019-01-11 18:00:00   6467.192500   6582.255000   6325.015000
# 50%    2019-09-18 12:00:00   8189.695000   8351.630000   8002.045000
# 75%    2020-05-25 06:00:00  10216.860000  10419.562500   9907.977500
# max    2021-01-30 00:00:00  40586.960000  41950.000000  38720.000000
# std                    NaN   5793.522832   6075.604427   5483.524463
#
#           close_USD         volume
# count   1000.000000    1000.000000
# mean    9310.335850   53100.498000
# min     3211.720000    5743.000000
# 25%     6466.762500   30045.750000
# 50%     8189.330000   43795.500000
# 75%    10220.170000   64909.250000
# max    40582.810000  402201.000000
# std     5846.917681   35329.832031

# %% [markdown]
# Visualizing the target variable

# %%
# Visualize closing price over time

plt.figure(figsize=(10, 4))

plt.plot(
    bitcoin["date"],
    bitcoin["close_USD"]
)

plt.title("Bitcoin Closing Price Over Time")
plt.xlabel("Date")
plt.ylabel("Close Price (USD)")

plt.ticklabel_format(
    style="plain",
    axis="y"
)

plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# ### Preparing data for recurrent modeling

# %%
# Prepare Bitcoin data for recurrent models

features = [
    "open_USD",
    "high_USD",
    "low_USD",
    "close_USD",
    "volume"
]

target_col = "close_USD"

bitcoin_model = bitcoin[["date"] + features].copy()

print("Unique dates:", bitcoin_model["date"].nunique())
print("Rows:", len(bitcoin_model))

scaler_bitcoin = MinMaxScaler(feature_range=(0, 1))

scaled_features = scaler_bitcoin.fit_transform(
    bitcoin_model[features]
)

look_back = 10                                                  # use 10 previous days to predict next close

target_index = features.index(target_col)
# Out:
# Unique dates: 1000
# Rows: 1000

# %% [markdown]
# ### Useful functions

# %%
# Function to create recurrent sequence windows

def create_sequences(dataset, target_index, look_back=10):

    X, y = [], []

    for i in range(len(dataset) - look_back):

        X.append(
            dataset[i:i + look_back, :]
        )                                                       # previous look_back days

        y.append(
            dataset[i + look_back, target_index]
        )                                                       # next day's close_USD

    return np.array(X), np.array(y)

# %%
# Function to visualize training curves

def plot_training_curves(history, title):

    fig, axes = plt.subplots(1, 2, figsize=(12, 4))

    # Loss
    axes[0].plot(
        history.history["loss"],
        label="Training Loss"
    )

    axes[0].plot(
        history.history["val_loss"],
        label="Validation Loss"
    )

    axes[0].set_title(title + " Loss")
    axes[0].set_xlabel("Epoch")
    axes[0].set_ylabel("MSE Loss")

    axes[0].legend()

    # MAE
    axes[1].plot(
        history.history["mean_absolute_error"],
        label="Training MAE"
    )

    axes[1].plot(
        history.history["val_mean_absolute_error"],
        label="Validation MAE"
    )

    axes[1].set_title(title + " MAE")
    axes[1].set_xlabel("Epoch")
    axes[1].set_ylabel("Mean Absolute Error")

    axes[1].legend()

    plt.tight_layout()

    plt.show()

# %%
# Function to evaluate forecasting performance

def evaluate_and_plot(
    model,
    trainX,
    testX,
    trainY,
    testY,
    scaler,
    target_index,
    title
):

    # Predictions
    train_pred = model.predict(trainX)
    test_pred = model.predict(testX)

    # Create arrays for inverse scaling
    train_dummy = np.zeros((len(train_pred), len(features)))
    test_dummy = np.zeros((len(test_pred), len(features)))

    train_dummy[:, target_index] = train_pred.flatten()
    test_dummy[:, target_index] = test_pred.flatten()

    trainY_dummy = np.zeros((len(trainY), len(features)))
    testY_dummy = np.zeros((len(testY), len(features)))

    trainY_dummy[:, target_index] = trainY
    testY_dummy[:, target_index] = testY

    # Inverse transform
    train_pred_inv = scaler.inverse_transform(train_dummy)[:, target_index]
    test_pred_inv = scaler.inverse_transform(test_dummy)[:, target_index]

    trainY_inv = scaler.inverse_transform(trainY_dummy)[:, target_index]
    testY_inv = scaler.inverse_transform(testY_dummy)[:, target_index]

    # Metrics
    train_rmse = np.sqrt(mean_squared_error(trainY_inv, train_pred_inv))
    test_rmse = np.sqrt(mean_squared_error(testY_inv, test_pred_inv))

    train_mae = mean_absolute_error(trainY_inv, train_pred_inv)
    test_mae = mean_absolute_error(testY_inv, test_pred_inv)

    print(f"{title} Train RMSE: {train_rmse:.2f}")
    print(f"{title} Test RMSE: {test_rmse:.2f}")

    print(f"{title} Train MAE: {train_mae:.2f}")
    print(f"{title} Test MAE: {test_mae:.2f}")

    # Plot predictions
    plt.figure(figsize=(10, 4))

    plt.plot(
        testY_inv,
        label="Actual"
    )

    plt.plot(
        test_pred_inv,
        label="Predicted"
    )

    plt.title(title + " Test Predictions")

    plt.xlabel("Test time index")
    plt.ylabel("Bitcoin Close Price (USD)")

    plt.ticklabel_format(
        style="plain",
        axis="y"
    )

    plt.legend()

    plt.show()

# %%
# Function to compare model metrics

def evaluate_metrics(
    model,
    testX,
    testY,
    scaler,
    target_index
):

    test_pred = model.predict(testX)

    test_dummy = np.zeros((len(test_pred), len(features)))
    test_dummy[:, target_index] = test_pred.flatten()

    testY_dummy = np.zeros((len(testY), len(features)))
    testY_dummy[:, target_index] = testY

    test_pred_inv = scaler.inverse_transform(test_dummy)[:, target_index]
    testY_inv = scaler.inverse_transform(testY_dummy)[:, target_index]

    rmse = np.sqrt(mean_squared_error(testY_inv, test_pred_inv))
    mae = mean_absolute_error(testY_inv, test_pred_inv)

    return rmse, mae

# %% [markdown]
# ### Creating train/test recurrent tensors

# %%
# Create train/test recurrent tensors

train_size = int(len(scaled_features) * 0.8)                    # chronological 80/20 split

train_bitcoin = scaled_features[:train_size]                    # earlier data
test_bitcoin = scaled_features[train_size:]                     # held-out future data

trainX_bitcoin, trainY_bitcoin = create_sequences(
    train_bitcoin,
    target_index,
    look_back
)

testX_bitcoin, testY_bitcoin = create_sequences(
    test_bitcoin,
    target_index,
    look_back
)

print("trainX_bitcoin shape:", trainX_bitcoin.shape)
print("testX_bitcoin shape:", testX_bitcoin.shape)
print("trainY_bitcoin shape:", trainY_bitcoin.shape)
print("testY_bitcoin shape:", testY_bitcoin.shape)
# Out:
# trainX_bitcoin shape: (790, 10, 5)
# testX_bitcoin shape: (190, 10, 5)
# trainY_bitcoin shape: (790,)
# testY_bitcoin shape: (190,)

# %% [markdown]
# ### Baseline SimpleRNN model

# %%
# Build and train baseline SimpleRNN model

simple_rnn_model = Sequential([
    SimpleRNN(
        8,                                     # small baseline recurrent layer
        activation="tanh",                     # standard activation for SimpleRNN
        input_shape=(look_back, trainX_bitcoin.shape[2])
    ),                                         # input shape = timesteps, features

    Dense(1)                                   # output layer: predict next close_USD value
])

simple_rnn_model.compile(
    optimizer="adam",                          # adaptive gradient-based optimizer
    loss="mean_squared_error",                 # regression loss
    metrics=["mean_absolute_error"]            # easier-to-interpret training metric
)

simple_rnn_history = simple_rnn_model.fit(
    trainX_bitcoin,
    trainY_bitcoin,
    epochs=50,                                 # baseline training limit
    batch_size=16,                             # update weights after each batch
    validation_split=0.2,                      # last 20% of training data used for validation
    shuffle=False,                             # preserve chronological order
    verbose=1
)
# Out:
# Epoch 1/50
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0108 - mean_absolute_error: 0.0820 - val_loss: 0.0113 - val_mean_absolute_error: 0.0747
# Epoch 2/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0041 - mean_absolute_error: 0.0477 - val_loss: 0.0080 - val_mean_absolute_error: 0.0571
# Epoch 3/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0029 - mean_absolute_error: 0.0402 - val_loss: 0.0062 - val_mean_absolute_error: 0.0496
# Epoch 4/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0022 - mean_absolute_error: 0.0343 - val_loss: 0.0049 - val_mean_absolute_error: 0.0438
# Epoch 5/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0018 - mean_absolute_error: 0.0304 - val_loss: 0.0039 - val_mean_absolute_error: 0.0391
# Epoch 6/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0015 - mean_absolute_error: 0.0279 - val_loss: 0.0032 - val_mean_absolute_error: 0.0353
# Epoch 7/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0013 - mean_absolute_error: 0.0259 - val_loss: 0.0026 - val_mean_absolute_error: 0.0323
# Epoch 8/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0011 - mean_absolute_error: 0.0242 - val_loss: 0.0022 - val_mean_absolute_error: 0.0299
# Epoch 9/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.6650e-04 - mean_absolute_error: 0.0227 - val_loss: 0.0019 - val_mean_absolute_error: 0.0280
# Epoch 10/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.5578e-04 - mean_absolute_error: 0.0214 - val_loss: 0.0016 - val_mean_absolute_error: 0.0264
# Epoch 11/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.6079e-04 - mean_absolute_error: 0.0202 - val_loss: 0.0014 - val_mean_absolute_error: 0.0250
# Epoch 12/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.7854e-04 - mean_absolute_error: 0.0191 - val_loss: 0.0013 - val_mean_absolute_error: 0.0239
# Epoch 13/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.0700e-04 - mean_absolute_error: 0.0181 - val_loss: 0.0012 - val_mean_absolute_error: 0.0228
# Epoch 14/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.4465e-04 - mean_absolute_error: 0.0172 - val_loss: 0.0010 - val_mean_absolute_error: 0.0218
# Epoch 15/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.9029e-04 - mean_absolute_error: 0.0163 - val_loss: 9.4630e-04 - val_mean_absolute_error: 0.0208
# Epoch 16/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.4292e-04 - mean_absolute_error: 0.0155 - val_loss: 8.6038e-04 - val_mean_absolute_error: 0.0199
# Epoch 17/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.0168e-04 - mean_absolute_error: 0.0148 - val_loss: 7.8424e-04 - val_mean_absolute_error: 0.0190
# Epoch 18/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.6580e-04 - mean_absolute_error: 0.0141 - val_loss: 7.1639e-04 - val_mean_absolute_error: 0.0182
# Epoch 19/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.3461e-04 - mean_absolute_error: 0.0135 - val_loss: 6.5576e-04 - val_mean_absolute_error: 0.0174
# Epoch 20/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.0751e-04 - mean_absolute_error: 0.0130 - val_loss: 6.0155e-04 - val_mean_absolute_error: 0.0166
# Epoch 21/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.8395e-04 - mean_absolute_error: 0.0125 - val_loss: 5.5307e-04 - val_mean_absolute_error: 0.0159
# Epoch 22/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.6346e-04 - mean_absolute_error: 0.0121 - val_loss: 5.0976e-04 - val_mean_absolute_error: 0.0153
# Epoch 23/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.4563e-04 - mean_absolute_error: 0.0116 - val_loss: 4.7113e-04 - val_mean_absolute_error: 0.0147
# Epoch 24/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.3011e-04 - mean_absolute_error: 0.0113 - val_loss: 4.3671e-04 - val_mean_absolute_error: 0.0142
# Epoch 25/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.1657e-04 - mean_absolute_error: 0.0109 - val_loss: 4.0609e-04 - val_mean_absolute_error: 0.0137
# Epoch 26/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.0475e-04 - mean_absolute_error: 0.0106 - val_loss: 3.7890e-04 - val_mean_absolute_error: 0.0133
# Epoch 27/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9443e-04 - mean_absolute_error: 0.0104 - val_loss: 3.5478e-04 - val_mean_absolute_error: 0.0129
# Epoch 28/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8540e-04 - mean_absolute_error: 0.0101 - val_loss: 3.3342e-04 - val_mean_absolute_error: 0.0125
# Epoch 29/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.7750e-04 - mean_absolute_error: 0.0099 - val_loss: 3.1452e-04 - val_mean_absolute_error: 0.0122
# Epoch 30/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.7058e-04 - mean_absolute_error: 0.0097 - val_loss: 2.9782e-04 - val_mean_absolute_error: 0.0118
# Epoch 31/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.6452e-04 - mean_absolute_error: 0.0095 - val_loss: 2.8306e-04 - val_mean_absolute_error: 0.0115
# Epoch 32/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5921e-04 - mean_absolute_error: 0.0093 - val_loss: 2.7003e-04 - val_mean_absolute_error: 0.0113
# Epoch 33/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5456e-04 - mean_absolute_error: 0.0091 - val_loss: 2.5853e-04 - val_mean_absolute_error: 0.0110
# Epoch 34/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.5048e-04 - mean_absolute_error: 0.0090 - val_loss: 2.4838e-04 - val_mean_absolute_error: 0.0108
# Epoch 35/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.4691e-04 - mean_absolute_error: 0.0089 - val_loss: 2.3943e-04 - val_mean_absolute_error: 0.0106
# Epoch 36/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4377e-04 - mean_absolute_error: 0.0087 - val_loss: 2.3152e-04 - val_mean_absolute_error: 0.0104
# Epoch 37/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.4101e-04 - mean_absolute_error: 0.0086 - val_loss: 2.2454e-04 - val_mean_absolute_error: 0.0102
# Epoch 38/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.3859e-04 - mean_absolute_error: 0.0085 - val_loss: 2.1838e-04 - val_mean_absolute_error: 0.0100
# Epoch 39/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.3646e-04 - mean_absolute_error: 0.0085 - val_loss: 2.1293e-04 - val_mean_absolute_error: 0.0099
# Epoch 40/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3457e-04 - mean_absolute_error: 0.0084 - val_loss: 2.0810e-04 - val_mean_absolute_error: 0.0098
# Epoch 41/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3290e-04 - mean_absolute_error: 0.0083 - val_loss: 2.0383e-04 - val_mean_absolute_error: 0.0097
# Epoch 42/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3141e-04 - mean_absolute_error: 0.0083 - val_loss: 2.0004e-04 - val_mean_absolute_error: 0.0096
# Epoch 43/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3007e-04 - mean_absolute_error: 0.0082 - val_loss: 1.9668e-04 - val_mean_absolute_error: 0.0095
# Epoch 44/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.2886e-04 - mean_absolute_error: 0.0082 - val_loss: 1.9370e-04 - val_mean_absolute_error: 0.0094
# Epoch 45/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.2777e-04 - mean_absolute_error: 0.0081 - val_loss: 1.9105e-04 - val_mean_absolute_error: 0.0094
# Epoch 46/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.2677e-04 - mean_absolute_error: 0.0081 - val_loss: 1.8868e-04 - val_mean_absolute_error: 0.0093
# Epoch 47/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.2584e-04 - mean_absolute_error: 0.0080 - val_loss: 1.8659e-04 - val_mean_absolute_error: 0.0093
# Epoch 48/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2498e-04 - mean_absolute_error: 0.0080 - val_loss: 1.8472e-04 - val_mean_absolute_error: 0.0092
# Epoch 49/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2417e-04 - mean_absolute_error: 0.0080 - val_loss: 1.8307e-04 - val_mean_absolute_error: 0.0092
# Epoch 50/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.2341e-04 - mean_absolute_error: 0.0079 - val_loss: 1.8160e-04 - val_mean_absolute_error: 0.0091

# %% [markdown]
# Visualizing training

# %%
# Visualize SimpleRNN training performance

plot_training_curves(
    simple_rnn_history,
    "Baseline SimpleRNN"
)

# %% [markdown]
# Evaluation on test data

# %%
# Evaluate SimpleRNN on held-out future test data

evaluate_and_plot(
    simple_rnn_model,
    trainX_bitcoin,
    testX_bitcoin,
    trainY_bitcoin,
    testY_bitcoin,
    scaler_bitcoin,
    target_index,
    "Baseline SimpleRNN"
)
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Baseline SimpleRNN Train RMSE: 493.52
# Baseline SimpleRNN Test RMSE: 3953.11
# Baseline SimpleRNN Train MAE: 364.83
# Baseline SimpleRNN Test MAE: 2409.82

# %% [markdown]
# ### Baseline LSTM Model

# %%
# Build and train baseline LSTM model

lstm_model = Sequential([
    LSTM(
        8,                                     # small baseline LSTM layer
        activation="tanh",                     # standard LSTM hidden-state activation
        input_shape=(look_back, trainX_bitcoin.shape[2])
    ),                                         # input shape = timesteps, features

    Dense(1)                                   # output layer: predict next close_USD value
])

lstm_model.compile(
    optimizer="adam",                          # adaptive gradient-based optimizer
    loss="mean_squared_error",                 # regression loss
    metrics=["mean_absolute_error"]            # easier-to-interpret training metric
)

lstm_history = lstm_model.fit(
    trainX_bitcoin,
    trainY_bitcoin,
    epochs=50,                                 # baseline training limit
    batch_size=16,                             # update weights after each batch
    validation_split=0.2,                      # last 20% of training data used for validation
    shuffle=False,                             # preserve chronological order
    verbose=1
)
# Out:
# Epoch 1/50
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 0.0018 - mean_absolute_error: 0.0332 - val_loss: 0.0052 - val_mean_absolute_error: 0.0536
# Epoch 2/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0011 - mean_absolute_error: 0.0257 - val_loss: 0.0043 - val_mean_absolute_error: 0.0484
# Epoch 3/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.7141e-04 - mean_absolute_error: 0.0183 - val_loss: 0.0033 - val_mean_absolute_error: 0.0409
# Epoch 4/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.8698e-04 - mean_absolute_error: 0.0150 - val_loss: 0.0024 - val_mean_absolute_error: 0.0340
# Epoch 5/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.2297e-04 - mean_absolute_error: 0.0139 - val_loss: 0.0019 - val_mean_absolute_error: 0.0293
# Epoch 6/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.8944e-04 - mean_absolute_error: 0.0132 - val_loss: 0.0015 - val_mean_absolute_error: 0.0259
# Epoch 7/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.6544e-04 - mean_absolute_error: 0.0126 - val_loss: 0.0012 - val_mean_absolute_error: 0.0231
# Epoch 8/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.4755e-04 - mean_absolute_error: 0.0122 - val_loss: 9.9588e-04 - val_mean_absolute_error: 0.0206
# Epoch 9/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.3489e-04 - mean_absolute_error: 0.0118 - val_loss: 8.1265e-04 - val_mean_absolute_error: 0.0184
# Epoch 10/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.2655e-04 - mean_absolute_error: 0.0116 - val_loss: 6.7026e-04 - val_mean_absolute_error: 0.0165
# Epoch 11/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.2148e-04 - mean_absolute_error: 0.0114 - val_loss: 5.6249e-04 - val_mean_absolute_error: 0.0149
# Epoch 12/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.1859e-04 - mean_absolute_error: 0.0112 - val_loss: 4.8299e-04 - val_mean_absolute_error: 0.0137
# Epoch 13/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.1692e-04 - mean_absolute_error: 0.0111 - val_loss: 4.2545e-04 - val_mean_absolute_error: 0.0128
# Epoch 14/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.1573e-04 - mean_absolute_error: 0.0110 - val_loss: 3.8417e-04 - val_mean_absolute_error: 0.0121
# Epoch 15/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.1456e-04 - mean_absolute_error: 0.0110 - val_loss: 3.5447e-04 - val_mean_absolute_error: 0.0117
# Epoch 16/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 2.1317e-04 - mean_absolute_error: 0.0109 - val_loss: 3.3280e-04 - val_mean_absolute_error: 0.0113
# Epoch 17/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.1150e-04 - mean_absolute_error: 0.0108 - val_loss: 3.1663e-04 - val_mean_absolute_error: 0.0110
# Epoch 18/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.0954e-04 - mean_absolute_error: 0.0108 - val_loss: 3.0425e-04 - val_mean_absolute_error: 0.0107
# Epoch 19/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.0735e-04 - mean_absolute_error: 0.0107 - val_loss: 2.9449e-04 - val_mean_absolute_error: 0.0106
# Epoch 20/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.0497e-04 - mean_absolute_error: 0.0106 - val_loss: 2.8657e-04 - val_mean_absolute_error: 0.0104
# Epoch 21/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.0247e-04 - mean_absolute_error: 0.0105 - val_loss: 2.7997e-04 - val_mean_absolute_error: 0.0103
# Epoch 22/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.9988e-04 - mean_absolute_error: 0.0105 - val_loss: 2.7434e-04 - val_mean_absolute_error: 0.0101
# Epoch 23/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.9723e-04 - mean_absolute_error: 0.0104 - val_loss: 2.6942e-04 - val_mean_absolute_error: 0.0100
# Epoch 24/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.9457e-04 - mean_absolute_error: 0.0103 - val_loss: 2.6506e-04 - val_mean_absolute_error: 0.0100
# Epoch 25/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.9189e-04 - mean_absolute_error: 0.0102 - val_loss: 2.6112e-04 - val_mean_absolute_error: 0.0099
# Epoch 26/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.8924e-04 - mean_absolute_error: 0.0101 - val_loss: 2.5753e-04 - val_mean_absolute_error: 0.0098
# Epoch 27/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.8660e-04 - mean_absolute_error: 0.0100 - val_loss: 2.5422e-04 - val_mean_absolute_error: 0.0098
# Epoch 28/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.8401e-04 - mean_absolute_error: 0.0100 - val_loss: 2.5114e-04 - val_mean_absolute_error: 0.0097
# Epoch 29/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.8147e-04 - mean_absolute_error: 0.0099 - val_loss: 2.4826e-04 - val_mean_absolute_error: 0.0097
# Epoch 30/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.7897e-04 - mean_absolute_error: 0.0098 - val_loss: 2.4556e-04 - val_mean_absolute_error: 0.0097
# Epoch 31/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.7653e-04 - mean_absolute_error: 0.0097 - val_loss: 2.4301e-04 - val_mean_absolute_error: 0.0096
# Epoch 32/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.7416e-04 - mean_absolute_error: 0.0096 - val_loss: 2.4059e-04 - val_mean_absolute_error: 0.0096
# Epoch 33/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.7184e-04 - mean_absolute_error: 0.0096 - val_loss: 2.3830e-04 - val_mean_absolute_error: 0.0096
# Epoch 34/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.6959e-04 - mean_absolute_error: 0.0095 - val_loss: 2.3612e-04 - val_mean_absolute_error: 0.0095
# Epoch 35/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.6740e-04 - mean_absolute_error: 0.0094 - val_loss: 2.3405e-04 - val_mean_absolute_error: 0.0095
# Epoch 36/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.6527e-04 - mean_absolute_error: 0.0093 - val_loss: 2.3207e-04 - val_mean_absolute_error: 0.0095
# Epoch 37/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.6321e-04 - mean_absolute_error: 0.0093 - val_loss: 2.3019e-04 - val_mean_absolute_error: 0.0095
# Epoch 38/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.6121e-04 - mean_absolute_error: 0.0092 - val_loss: 2.2839e-04 - val_mean_absolute_error: 0.0095
# Epoch 39/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5927e-04 - mean_absolute_error: 0.0091 - val_loss: 2.2666e-04 - val_mean_absolute_error: 0.0094
# Epoch 40/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.5739e-04 - mean_absolute_error: 0.0091 - val_loss: 2.2501e-04 - val_mean_absolute_error: 0.0094
# Epoch 41/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5557e-04 - mean_absolute_error: 0.0090 - val_loss: 2.2343e-04 - val_mean_absolute_error: 0.0094
# Epoch 42/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.5381e-04 - mean_absolute_error: 0.0090 - val_loss: 2.2191e-04 - val_mean_absolute_error: 0.0094
# Epoch 43/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.5210e-04 - mean_absolute_error: 0.0089 - val_loss: 2.2045e-04 - val_mean_absolute_error: 0.0094
# Epoch 44/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.5044e-04 - mean_absolute_error: 0.0088 - val_loss: 2.1904e-04 - val_mean_absolute_error: 0.0094
# Epoch 45/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.4884e-04 - mean_absolute_error: 0.0088 - val_loss: 2.1768e-04 - val_mean_absolute_error: 0.0094
# Epoch 46/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.4728e-04 - mean_absolute_error: 0.0087 - val_loss: 2.1637e-04 - val_mean_absolute_error: 0.0094
# Epoch 47/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4577e-04 - mean_absolute_error: 0.0087 - val_loss: 2.1510e-04 - val_mean_absolute_error: 0.0094
# Epoch 48/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.4431e-04 - mean_absolute_error: 0.0086 - val_loss: 2.1387e-04 - val_mean_absolute_error: 0.0094
# Epoch 49/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.4289e-04 - mean_absolute_error: 0.0086 - val_loss: 2.1267e-04 - val_mean_absolute_error: 0.0094
# Epoch 50/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.4151e-04 - mean_absolute_error: 0.0086 - val_loss: 2.1150e-04 - val_mean_absolute_error: 0.0094

# %% [markdown]
# Visualizing training

# %%
# Visualize LSTM training performance

plot_training_curves(
    lstm_history,
    "Baseline LSTM"
)

# %% [markdown]
# Evaluation on test data

# %%
# Evaluate LSTM on held-out future test data

evaluate_and_plot(
    lstm_model,
    trainX_bitcoin,
    testX_bitcoin,
    trainY_bitcoin,
    testY_bitcoin,
    scaler_bitcoin,
    target_index,
    "Baseline LSTM"
)
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Baseline LSTM Train RMSE: 434.39
# Baseline LSTM Test RMSE: 2398.13
# Baseline LSTM Train MAE: 299.69
# Baseline LSTM Test MAE: 1580.11

# %% [markdown]
# ### Baseline GRU model

# %%
# Build and train baseline GRU model

gru_model = Sequential([
    GRU(
        8,                                      # intentionally small baseline GRU layer
        activation="tanh",                     # standard GRU hidden-state activation
        input_shape=(look_back, trainX_bitcoin.shape[2])
    ),                                         # input shape = timesteps, features

    Dense(1)                                   # output layer: predict next close_USD value
])

gru_model.compile(
    optimizer="adam",                          # adaptive gradient-based optimizer
    loss="mean_squared_error",                 # regression loss
    metrics=["mean_absolute_error"]            # easier-to-interpret training metric
)

gru_history = gru_model.fit(
    trainX_bitcoin,
    trainY_bitcoin,
    epochs=50,                                 # baseline training limit
    batch_size=16,                             # update weights after each batch
    validation_split=0.2,                      # last 20% of training data used for validation
    shuffle=False,                             # preserve chronological order
    verbose=1
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0039 - mean_absolute_error: 0.0515 - val_loss: 0.0022 - val_mean_absolute_error: 0.0363
# Epoch 2/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0011 - mean_absolute_error: 0.0279 - val_loss: 0.0020 - val_mean_absolute_error: 0.0395
# Epoch 3/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.3650e-04 - mean_absolute_error: 0.0147 - val_loss: 8.5610e-04 - val_mean_absolute_error: 0.0239
# Epoch 4/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5692e-04 - mean_absolute_error: 0.0092 - val_loss: 3.7739e-04 - val_mean_absolute_error: 0.0138
# Epoch 5/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.6610e-04 - mean_absolute_error: 0.0093 - val_loss: 2.3522e-04 - val_mean_absolute_error: 0.0105
# Epoch 6/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.8008e-04 - mean_absolute_error: 0.0095 - val_loss: 1.7585e-04 - val_mean_absolute_error: 0.0090
# Epoch 7/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.8698e-04 - mean_absolute_error: 0.0096 - val_loss: 1.4778e-04 - val_mean_absolute_error: 0.0082
# Epoch 8/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.8542e-04 - mean_absolute_error: 0.0096 - val_loss: 1.3687e-04 - val_mean_absolute_error: 0.0079
# Epoch 9/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.7644e-04 - mean_absolute_error: 0.0094 - val_loss: 1.3468e-04 - val_mean_absolute_error: 0.0080
# Epoch 10/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.6288e-04 - mean_absolute_error: 0.0091 - val_loss: 1.3660e-04 - val_mean_absolute_error: 0.0083
# Epoch 11/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4787e-04 - mean_absolute_error: 0.0087 - val_loss: 1.4010e-04 - val_mean_absolute_error: 0.0085
# Epoch 12/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3379e-04 - mean_absolute_error: 0.0083 - val_loss: 1.4387e-04 - val_mean_absolute_error: 0.0088
# Epoch 13/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.2194e-04 - mean_absolute_error: 0.0080 - val_loss: 1.4737e-04 - val_mean_absolute_error: 0.0090
# Epoch 14/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.1275e-04 - mean_absolute_error: 0.0076 - val_loss: 1.5053e-04 - val_mean_absolute_error: 0.0091
# Epoch 15/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.0608e-04 - mean_absolute_error: 0.0074 - val_loss: 1.5349e-04 - val_mean_absolute_error: 0.0093
# Epoch 16/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.0154e-04 - mean_absolute_error: 0.0072 - val_loss: 1.5648e-04 - val_mean_absolute_error: 0.0094
# Epoch 17/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.8688e-05 - mean_absolute_error: 0.0071 - val_loss: 1.5971e-04 - val_mean_absolute_error: 0.0096
# Epoch 18/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.7116e-05 - mean_absolute_error: 0.0070 - val_loss: 1.6333e-04 - val_mean_absolute_error: 0.0098
# Epoch 19/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 9.6518e-05 - mean_absolute_error: 0.0070 - val_loss: 1.6747e-04 - val_mean_absolute_error: 0.0100
# Epoch 20/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 9.6686e-05 - mean_absolute_error: 0.0070 - val_loss: 1.7219e-04 - val_mean_absolute_error: 0.0102
# Epoch 21/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 9.7492e-05 - mean_absolute_error: 0.0070 - val_loss: 1.7759e-04 - val_mean_absolute_error: 0.0104
# Epoch 22/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 9.8869e-05 - mean_absolute_error: 0.0071 - val_loss: 1.8374e-04 - val_mean_absolute_error: 0.0107
# Epoch 23/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.0079e-04 - mean_absolute_error: 0.0072 - val_loss: 1.9071e-04 - val_mean_absolute_error: 0.0111
# Epoch 24/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.0323e-04 - mean_absolute_error: 0.0073 - val_loss: 1.9856e-04 - val_mean_absolute_error: 0.0114
# Epoch 25/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.0620e-04 - mean_absolute_error: 0.0074 - val_loss: 2.0731e-04 - val_mean_absolute_error: 0.0117
# Epoch 26/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.0967e-04 - mean_absolute_error: 0.0076 - val_loss: 2.1692e-04 - val_mean_absolute_error: 0.0121
# Epoch 27/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.1360e-04 - mean_absolute_error: 0.0078 - val_loss: 2.2728e-04 - val_mean_absolute_error: 0.0125
# Epoch 28/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.1791e-04 - mean_absolute_error: 0.0080 - val_loss: 2.3816e-04 - val_mean_absolute_error: 0.0129
# Epoch 29/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.2248e-04 - mean_absolute_error: 0.0082 - val_loss: 2.4922e-04 - val_mean_absolute_error: 0.0133
# Epoch 30/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.2712e-04 - mean_absolute_error: 0.0084 - val_loss: 2.5998e-04 - val_mean_absolute_error: 0.0136
# Epoch 31/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3159e-04 - mean_absolute_error: 0.0086 - val_loss: 2.6989e-04 - val_mean_absolute_error: 0.0139
# Epoch 32/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3563e-04 - mean_absolute_error: 0.0088 - val_loss: 2.7837e-04 - val_mean_absolute_error: 0.0142
# Epoch 33/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3897e-04 - mean_absolute_error: 0.0089 - val_loss: 2.8495e-04 - val_mean_absolute_error: 0.0144
# Epoch 34/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4142e-04 - mean_absolute_error: 0.0090 - val_loss: 2.8934e-04 - val_mean_absolute_error: 0.0145
# Epoch 35/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4289e-04 - mean_absolute_error: 0.0091 - val_loss: 2.9156e-04 - val_mean_absolute_error: 0.0146
# Epoch 36/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4342e-04 - mean_absolute_error: 0.0091 - val_loss: 2.9192e-04 - val_mean_absolute_error: 0.0146
# Epoch 37/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4320e-04 - mean_absolute_error: 0.0091 - val_loss: 2.9093e-04 - val_mean_absolute_error: 0.0145
# Epoch 38/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4246e-04 - mean_absolute_error: 0.0091 - val_loss: 2.8919e-04 - val_mean_absolute_error: 0.0145
# Epoch 39/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4147e-04 - mean_absolute_error: 0.0090 - val_loss: 2.8722e-04 - val_mean_absolute_error: 0.0144
# Epoch 40/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.4044e-04 - mean_absolute_error: 0.0090 - val_loss: 2.8540e-04 - val_mean_absolute_error: 0.0144
# Epoch 41/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3950e-04 - mean_absolute_error: 0.0090 - val_loss: 2.8392e-04 - val_mean_absolute_error: 0.0143
# Epoch 42/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3873e-04 - mean_absolute_error: 0.0089 - val_loss: 2.8284e-04 - val_mean_absolute_error: 0.0143
# Epoch 43/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3812e-04 - mean_absolute_error: 0.0089 - val_loss: 2.8208e-04 - val_mean_absolute_error: 0.0143
# Epoch 44/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3764e-04 - mean_absolute_error: 0.0089 - val_loss: 2.8152e-04 - val_mean_absolute_error: 0.0142
# Epoch 45/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3723e-04 - mean_absolute_error: 0.0089 - val_loss: 2.8104e-04 - val_mean_absolute_error: 0.0142
# Epoch 46/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3683e-04 - mean_absolute_error: 0.0088 - val_loss: 2.8052e-04 - val_mean_absolute_error: 0.0142
# Epoch 47/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3640e-04 - mean_absolute_error: 0.0088 - val_loss: 2.7990e-04 - val_mean_absolute_error: 0.0142
# Epoch 48/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3592e-04 - mean_absolute_error: 0.0088 - val_loss: 2.7916e-04 - val_mean_absolute_error: 0.0142
# Epoch 49/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3539e-04 - mean_absolute_error: 0.0088 - val_loss: 2.7829e-04 - val_mean_absolute_error: 0.0141
# Epoch 50/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.3481e-04 - mean_absolute_error: 0.0088 - val_loss: 2.7734e-04 - val_mean_absolute_error: 0.0141

# %% [markdown]
# Visualizing training

# %%
# Visualize GRU training performance

plot_training_curves(
    gru_history,
    "Baseline GRU"
)

# %% [markdown]
# Evaluation on test data

# %%
# Evaluate GRU on held-out future test data

evaluate_and_plot(
    gru_model,
    trainX_bitcoin,
    testX_bitcoin,
    trainY_bitcoin,
    testY_bitcoin,
    scaler_bitcoin,
    target_index,
    "Baseline GRU"
)
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Baseline GRU Train RMSE: 560.80
# Baseline GRU Test RMSE: 4732.63
# Baseline GRU Train MAE: 438.16
# Baseline GRU Test MAE: 3248.34

# %% [markdown]
# ### Activity: Improving Forecasting Models
#
# Improve each of the baseline three recurrent models (SimpleRNN, LSTM, and GRU) and compare their forecasting performance against the XGBoost models shown below. You should provide the code for each improved model and include a markdown cell after each model describing what you changed, what you explored, and how the changes affected performance. After completing your experiments, provide a short overall summary discussing which approaches appeared most effective, which models were easiest or hardest to tune, and what tradeoffs you observed between model complexity, training stability, and forecasting performance.

# %%
# Improved SimpleRNN model
# Changes: deeper stack (32 → 16 units), Dropout regularization,
# larger look_back (30 days), EarlyStopping to prevent overfitting

from tensorflow.keras.layers import Dropout

look_back_v2 = 30

trainX_rnn2, trainY_rnn2 = create_sequences(scaled_features[:train_size], target_index, look_back_v2)
testX_rnn2,  testY_rnn2  = create_sequences(scaled_features[train_size:],  target_index, look_back_v2)

improved_rnn_model = Sequential([
    SimpleRNN(
        32,
        activation="tanh",
        return_sequences=True,                  # pass hidden states to next RNN layer
        input_shape=(look_back_v2, trainX_rnn2.shape[2])
    ),
    Dropout(0.2),
    SimpleRNN(
        16,
        activation="tanh"
    ),
    Dropout(0.2),
    Dense(1)
])

improved_rnn_model.compile(
    optimizer="adam",
    loss="mean_squared_error",
    metrics=["mean_absolute_error"]
)

early_stop = EarlyStopping(
    monitor="val_loss",
    patience=10,
    restore_best_weights=True
)

improved_rnn_history = improved_rnn_model.fit(
    trainX_rnn2,
    trainY_rnn2,
    epochs=100,
    batch_size=32,
    validation_split=0.2,
    shuffle=False,
    callbacks=[early_stop],
    verbose=1
)

plot_training_curves(improved_rnn_history, "Improved SimpleRNN")

evaluate_and_plot(
    improved_rnn_model,
    trainX_rnn2, testX_rnn2,
    trainY_rnn2, testY_rnn2,
    scaler_bitcoin, target_index,
    "Improved SimpleRNN"
)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.0887 - mean_absolute_error: 0.2314 - val_loss: 0.0520 - val_mean_absolute_error: 0.1703
# Epoch 2/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0445 - mean_absolute_error: 0.1666 - val_loss: 0.0272 - val_mean_absolute_error: 0.1189
# Epoch 3/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0325 - mean_absolute_error: 0.1422 - val_loss: 0.0418 - val_mean_absolute_error: 0.1707
# Epoch 4/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0296 - mean_absolute_error: 0.1336 - val_loss: 0.0312 - val_mean_absolute_error: 0.1520
# Epoch 5/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0202 - mean_absolute_error: 0.1121 - val_loss: 0.0092 - val_mean_absolute_error: 0.0691
# Epoch 6/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0135 - mean_absolute_error: 0.0853 - val_loss: 0.0070 - val_mean_absolute_error: 0.0598
# Epoch 7/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0122 - mean_absolute_error: 0.0844 - val_loss: 0.0057 - val_mean_absolute_error: 0.0542
# Epoch 8/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0101 - mean_absolute_error: 0.0769 - val_loss: 0.0053 - val_mean_absolute_error: 0.0532
# Epoch 9/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0092 - mean_absolute_error: 0.0723 - val_loss: 0.0048 - val_mean_absolute_error: 0.0501
# Epoch 10/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0088 - mean_absolute_error: 0.0693 - val_loss: 0.0038 - val_mean_absolute_error: 0.0449
# Epoch 11/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0083 - mean_absolute_error: 0.0695 - val_loss: 0.0034 - val_mean_absolute_error: 0.0429
# Epoch 12/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0071 - mean_absolute_error: 0.0660 - val_loss: 0.0034 - val_mean_absolute_error: 0.0439
# Epoch 13/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0062 - mean_absolute_error: 0.0604 - val_loss: 0.0022 - val_mean_absolute_error: 0.0342
# Epoch 14/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0053 - mean_absolute_error: 0.0555 - val_loss: 0.0024 - val_mean_absolute_error: 0.0370
# Epoch 15/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0045 - mean_absolute_error: 0.0523 - val_loss: 0.0019 - val_mean_absolute_error: 0.0316
# Epoch 16/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0042 - mean_absolute_error: 0.0501 - val_loss: 0.0019 - val_mean_absolute_error: 0.0317
# Epoch 17/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0040 - mean_absolute_error: 0.0485 - val_loss: 0.0019 - val_mean_absolute_error: 0.0323
# Epoch 18/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0041 - mean_absolute_error: 0.0476 - val_loss: 0.0015 - val_mean_absolute_error: 0.0275
# Epoch 19/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0039 - mean_absolute_error: 0.0463 - val_loss: 0.0013 - val_mean_absolute_error: 0.0253
# Epoch 20/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0038 - mean_absolute_error: 0.0472 - val_loss: 0.0014 - val_mean_absolute_error: 0.0278
# Epoch 21/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0036 - mean_absolute_error: 0.0445 - val_loss: 8.8421e-04 - val_mean_absolute_error: 0.0212
# Epoch 22/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0033 - mean_absolute_error: 0.0428 - val_loss: 9.2535e-04 - val_mean_absolute_error: 0.0217
# Epoch 23/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0029 - mean_absolute_error: 0.0403 - val_loss: 7.0502e-04 - val_mean_absolute_error: 0.0190
# Epoch 24/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0030 - mean_absolute_error: 0.0408 - val_loss: 6.7260e-04 - val_mean_absolute_error: 0.0187
# Epoch 25/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0027 - mean_absolute_error: 0.0377 - val_loss: 0.0010 - val_mean_absolute_error: 0.0233
# Epoch 26/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0024 - mean_absolute_error: 0.0376 - val_loss: 6.8411e-04 - val_mean_absolute_error: 0.0183
# Epoch 27/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0023 - mean_absolute_error: 0.0363 - val_loss: 5.3560e-04 - val_mean_absolute_error: 0.0162
# Epoch 28/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0023 - mean_absolute_error: 0.0362 - val_loss: 4.9262e-04 - val_mean_absolute_error: 0.0155
# Epoch 29/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0020 - mean_absolute_error: 0.0342 - val_loss: 6.1457e-04 - val_mean_absolute_error: 0.0178
# Epoch 30/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0020 - mean_absolute_error: 0.0341 - val_loss: 5.4903e-04 - val_mean_absolute_error: 0.0168
# Epoch 31/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0020 - mean_absolute_error: 0.0330 - val_loss: 4.5151e-04 - val_mean_absolute_error: 0.0149
# Epoch 32/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0018 - mean_absolute_error: 0.0319 - val_loss: 4.7383e-04 - val_mean_absolute_error: 0.0155
# Epoch 33/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0018 - mean_absolute_error: 0.0321 - val_loss: 4.1340e-04 - val_mean_absolute_error: 0.0145
# Epoch 34/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0019 - mean_absolute_error: 0.0327 - val_loss: 3.9278e-04 - val_mean_absolute_error: 0.0151
# Epoch 35/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0017 - mean_absolute_error: 0.0314 - val_loss: 3.2646e-04 - val_mean_absolute_error: 0.0125
# Epoch 36/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0016 - mean_absolute_error: 0.0297 - val_loss: 4.3376e-04 - val_mean_absolute_error: 0.0147
# Epoch 37/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0015 - mean_absolute_error: 0.0296 - val_loss: 3.2495e-04 - val_mean_absolute_error: 0.0128
# Epoch 38/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0016 - mean_absolute_error: 0.0291 - val_loss: 2.9883e-04 - val_mean_absolute_error: 0.0118
# Epoch 39/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0014 - mean_absolute_error: 0.0285 - val_loss: 3.3128e-04 - val_mean_absolute_error: 0.0143
# Epoch 40/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0017 - mean_absolute_error: 0.0300 - val_loss: 2.4959e-04 - val_mean_absolute_error: 0.0115
# Epoch 41/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0014 - mean_absolute_error: 0.0289 - val_loss: 3.5621e-04 - val_mean_absolute_error: 0.0136
# Epoch 42/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0016 - mean_absolute_error: 0.0299 - val_loss: 2.7415e-04 - val_mean_absolute_error: 0.0115
# Epoch 43/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0013 - mean_absolute_error: 0.0279 - val_loss: 2.3240e-04 - val_mean_absolute_error: 0.0111
# Epoch 44/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0013 - mean_absolute_error: 0.0274 - val_loss: 3.5863e-04 - val_mean_absolute_error: 0.0155
# Epoch 45/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0013 - mean_absolute_error: 0.0270 - val_loss: 2.1982e-04 - val_mean_absolute_error: 0.0108
# Epoch 46/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0013 - mean_absolute_error: 0.0272 - val_loss: 3.0499e-04 - val_mean_absolute_error: 0.0137
# Epoch 47/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0013 - mean_absolute_error: 0.0261 - val_loss: 2.1186e-04 - val_mean_absolute_error: 0.0099
# Epoch 48/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0013 - mean_absolute_error: 0.0262 - val_loss: 3.4507e-04 - val_mean_absolute_error: 0.0130
# Epoch 49/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0012 - mean_absolute_error: 0.0254 - val_loss: 3.4111e-04 - val_mean_absolute_error: 0.0131
# Epoch 50/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0010 - mean_absolute_error: 0.0239 - val_loss: 2.4947e-04 - val_mean_absolute_error: 0.0105
# Epoch 51/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0010 - mean_absolute_error: 0.0239 - val_loss: 2.1261e-04 - val_mean_absolute_error: 0.0098
# Epoch 52/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0010 - mean_absolute_error: 0.0241 - val_loss: 2.0452e-04 - val_mean_absolute_error: 0.0096
# Epoch 53/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 9.9694e-04 - mean_absolute_error: 0.0243 - val_loss: 2.0986e-04 - val_mean_absolute_error: 0.0096
# Epoch 54/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0011 - mean_absolute_error: 0.0242 - val_loss: 1.9925e-04 - val_mean_absolute_error: 0.0097
# Epoch 55/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.4621e-04 - mean_absolute_error: 0.0222 - val_loss: 2.0453e-04 - val_mean_absolute_error: 0.0102
# Epoch 56/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.2164e-04 - mean_absolute_error: 0.0225 - val_loss: 1.9833e-04 - val_mean_absolute_error: 0.0097
# Epoch 57/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 8.6034e-04 - mean_absolute_error: 0.0221 - val_loss: 1.9300e-04 - val_mean_absolute_error: 0.0095
# Epoch 58/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 9.3349e-04 - mean_absolute_error: 0.0225 - val_loss: 1.9958e-04 - val_mean_absolute_error: 0.0093
# Epoch 59/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0010 - mean_absolute_error: 0.0236 - val_loss: 2.7556e-04 - val_mean_absolute_error: 0.0114
# Epoch 60/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 9.9313e-04 - mean_absolute_error: 0.0236 - val_loss: 2.6713e-04 - val_mean_absolute_error: 0.0111
# Epoch 61/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.6167e-04 - mean_absolute_error: 0.0236 - val_loss: 3.3098e-04 - val_mean_absolute_error: 0.0135
# Epoch 62/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.5090e-04 - mean_absolute_error: 0.0224 - val_loss: 1.7687e-04 - val_mean_absolute_error: 0.0090
# Epoch 63/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 9.2531e-04 - mean_absolute_error: 0.0226 - val_loss: 2.1950e-04 - val_mean_absolute_error: 0.0113
# Epoch 64/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 8.2622e-04 - mean_absolute_error: 0.0214 - val_loss: 2.2415e-04 - val_mean_absolute_error: 0.0117
# Epoch 65/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 6.5937e-04 - mean_absolute_error: 0.0193 - val_loss: 1.7379e-04 - val_mean_absolute_error: 0.0086
# Epoch 66/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.5700e-04 - mean_absolute_error: 0.0208 - val_loss: 2.1828e-04 - val_mean_absolute_error: 0.0104
# Epoch 67/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 7.8357e-04 - mean_absolute_error: 0.0210 - val_loss: 1.9163e-04 - val_mean_absolute_error: 0.0092
# Epoch 68/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 6.5477e-04 - mean_absolute_error: 0.0193 - val_loss: 1.5473e-04 - val_mean_absolute_error: 0.0085
# Epoch 69/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.3474e-04 - mean_absolute_error: 0.0204 - val_loss: 1.7817e-04 - val_mean_absolute_error: 0.0101
# Epoch 70/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 7.7563e-04 - mean_absolute_error: 0.0202 - val_loss: 1.4983e-04 - val_mean_absolute_error: 0.0084
# Epoch 71/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 6.9474e-04 - mean_absolute_error: 0.0196 - val_loss: 1.6849e-04 - val_mean_absolute_error: 0.0085
# Epoch 72/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 5.8218e-04 - mean_absolute_error: 0.0178 - val_loss: 2.0576e-04 - val_mean_absolute_error: 0.0094
# Epoch 73/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 7.5188e-04 - mean_absolute_error: 0.0206 - val_loss: 2.3400e-04 - val_mean_absolute_error: 0.0108
# Epoch 74/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 6.5721e-04 - mean_absolute_error: 0.0194 - val_loss: 1.5031e-04 - val_mean_absolute_error: 0.0081
# Epoch 75/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 6.4979e-04 - mean_absolute_error: 0.0194 - val_loss: 2.0567e-04 - val_mean_absolute_error: 0.0094
# Epoch 76/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 6.7096e-04 - mean_absolute_error: 0.0193 - val_loss: 2.0088e-04 - val_mean_absolute_error: 0.0091
# Epoch 77/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 7.1017e-04 - mean_absolute_error: 0.0201 - val_loss: 2.7828e-04 - val_mean_absolute_error: 0.0121
# Epoch 78/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 6.1444e-04 - mean_absolute_error: 0.0188 - val_loss: 1.9618e-04 - val_mean_absolute_error: 0.0092
# Epoch 79/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 6.0116e-04 - mean_absolute_error: 0.0184 - val_loss: 1.8303e-04 - val_mean_absolute_error: 0.0086
# Epoch 80/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 6.3882e-04 - mean_absolute_error: 0.0188 - val_loss: 1.9397e-04 - val_mean_absolute_error: 0.0106
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Improved SimpleRNN Train RMSE: 374.90
# Improved SimpleRNN Test RMSE: 2358.62
# Improved SimpleRNN Train MAE: 262.76
# Improved SimpleRNN Test MAE: 1516.68

# %% [markdown]
# **SimpleRNN observations**
#
# Baseline (look_back=10, 8 units, 50 epochs): **Test RMSE 3,953 | MAE 2,410**
#
# Changes made:
# - Extended `look_back` from 10 → 30 days.
# - Stacked two SimpleRNN layers (32 → 16 units) with `return_sequences=True`.
# - Added 20% Dropout after each layer.
# - Raised epoch ceiling to 100 with `EarlyStopping(patience=10)`; training ran to epoch 80.
#
# Improved result: **Test RMSE 2,359 | MAE 1,517** — ~40% reduction in test RMSE. Train RMSE also dropped (494 → 375), and the train/val gap narrowed, indicating better generalisation. The longer look-back window was the most impactful single change; Dropout kept training stable throughout all 80 epochs. SimpleRNN still lags the LSTM baseline — expected, since the vanishing-gradient problem limits how much of the 30-day window it can actually retain.

# %%
# Improved LSTM model
# Changes: stacked LSTM (64 → 32 units), recurrent_dropout inside LSTM,
# look_back 30, EarlyStopping, smaller learning rate via Adam

improved_lstm_model = Sequential([
    LSTM(
        64,
        activation="tanh",
        recurrent_dropout=0.1,                  # dropout on recurrent connections
        return_sequences=True,
        input_shape=(look_back_v2, trainX_rnn2.shape[2])
    ),
    Dropout(0.2),
    LSTM(
        32,
        activation="tanh",
        recurrent_dropout=0.1
    ),
    Dropout(0.2),
    Dense(1)
])

improved_lstm_model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss="mean_squared_error",
    metrics=["mean_absolute_error"]
)

improved_lstm_history = improved_lstm_model.fit(
    trainX_rnn2,
    trainY_rnn2,
    epochs=100,
    batch_size=32,
    validation_split=0.2,
    shuffle=False,
    callbacks=[early_stop],
    verbose=1
)

plot_training_curves(improved_lstm_history, "Improved LSTM")

evaluate_and_plot(
    improved_lstm_model,
    trainX_rnn2, testX_rnn2,
    trainY_rnn2, testY_rnn2,
    scaler_bitcoin, target_index,
    "Improved LSTM"
)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 113ms/step - loss: 0.0020 - mean_absolute_error: 0.0368 - val_loss: 0.0014 - val_mean_absolute_error: 0.0302
# Epoch 2/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 9.4960e-04 - mean_absolute_error: 0.0237 - val_loss: 0.0010 - val_mean_absolute_error: 0.0251
# Epoch 3/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 103ms/step - loss: 7.0762e-04 - mean_absolute_error: 0.0199 - val_loss: 7.4301e-04 - val_mean_absolute_error: 0.0197
# Epoch 4/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 6.0332e-04 - mean_absolute_error: 0.0183 - val_loss: 4.4406e-04 - val_mean_absolute_error: 0.0132
# Epoch 5/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 5.1000e-04 - mean_absolute_error: 0.0164 - val_loss: 4.0221e-04 - val_mean_absolute_error: 0.0121
# Epoch 6/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 5.2709e-04 - mean_absolute_error: 0.0166 - val_loss: 6.2116e-04 - val_mean_absolute_error: 0.0176
# Epoch 7/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 5.2765e-04 - mean_absolute_error: 0.0168 - val_loss: 5.0352e-04 - val_mean_absolute_error: 0.0150
# Epoch 8/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 5.2357e-04 - mean_absolute_error: 0.0168 - val_loss: 5.1412e-04 - val_mean_absolute_error: 0.0152
# Epoch 9/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 5.0466e-04 - mean_absolute_error: 0.0164 - val_loss: 4.8884e-04 - val_mean_absolute_error: 0.0149
# Epoch 10/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 5.7189e-04 - mean_absolute_error: 0.0177 - val_loss: 5.7909e-04 - val_mean_absolute_error: 0.0173
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Improved LSTM Train RMSE: 1168.75
# Improved LSTM Test RMSE: 2498.52
# Improved LSTM Train MAE: 980.13
# Improved LSTM Test MAE: 1661.61

# %% [markdown]
# **LSTM observations**
#
# Baseline (look_back=10, 8 units, 50 epochs): **Test RMSE 2,398 | MAE 1,580**
#
# Changes made:
# - Stacked two LSTM layers (64 → 32 units).
# - Added `recurrent_dropout=0.1` inside each LSTM cell plus 20% standard Dropout between layers.
# - Extended `look_back` to 30 with `EarlyStopping(patience=10)`; early stopping fired within the first 15 epochs.
#
# Improved result: **Test RMSE 2,499 | MAE 1,662** — marginally *worse* than the baseline. The heavy regularisation (`recurrent_dropout` combined with Dropout) slowed convergence enough that early stopping triggered before the model could fully leverage the extra capacity. With more training time or looser regularisation the stacked LSTM likely would have improved further; as configured, it slightly underfits relative to the baseline.

# %%
# Improved GRU model
# Changes: Bidirectional wrapper on first GRU layer, stacked GRU (64 → 32),
# recurrent_dropout, look_back 30, EarlyStopping

from tensorflow.keras.layers import Bidirectional

improved_gru_model = Sequential([
    Bidirectional(
        GRU(
            64,
            activation="tanh",
            recurrent_dropout=0.1,
            return_sequences=True
        ),
        input_shape=(look_back_v2, trainX_rnn2.shape[2])
    ),                                          # reads sequence forward AND backward
    Dropout(0.2),
    GRU(
        32,
        activation="tanh",
        recurrent_dropout=0.1
    ),
    Dropout(0.2),
    Dense(1)
])

improved_gru_model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss="mean_squared_error",
    metrics=["mean_absolute_error"]
)

improved_gru_history = improved_gru_model.fit(
    trainX_rnn2,
    trainY_rnn2,
    epochs=100,
    batch_size=32,
    validation_split=0.2,
    shuffle=False,
    callbacks=[early_stop],
    verbose=1
)

plot_training_curves(improved_gru_history, "Improved GRU")

evaluate_and_plot(
    improved_gru_model,
    trainX_rnn2, testX_rnn2,
    trainY_rnn2, testY_rnn2,
    scaler_bitcoin, target_index,
    "Improved GRU"
)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 11s 133ms/step - loss: 0.0067 - mean_absolute_error: 0.0682 - val_loss: 0.0027 - val_mean_absolute_error: 0.0469
# Epoch 2/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 0.0011 - mean_absolute_error: 0.0282 - val_loss: 2.4128e-04 - val_mean_absolute_error: 0.0109
# Epoch 3/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 4s 137ms/step - loss: 5.1386e-04 - mean_absolute_error: 0.0162 - val_loss: 2.2965e-04 - val_mean_absolute_error: 0.0093
# Epoch 4/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - loss: 4.6021e-04 - mean_absolute_error: 0.0162 - val_loss: 2.4846e-04 - val_mean_absolute_error: 0.0097
# Epoch 5/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 81ms/step - loss: 4.1130e-04 - mean_absolute_error: 0.0148 - val_loss: 2.2154e-04 - val_mean_absolute_error: 0.0094
# Epoch 6/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 3.5766e-04 - mean_absolute_error: 0.0139 - val_loss: 2.2049e-04 - val_mean_absolute_error: 0.0102
# Epoch 7/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 4.2815e-04 - mean_absolute_error: 0.0146 - val_loss: 1.9480e-04 - val_mean_absolute_error: 0.0090
# Epoch 8/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - loss: 3.6754e-04 - mean_absolute_error: 0.0141 - val_loss: 2.1660e-04 - val_mean_absolute_error: 0.0107
# Epoch 9/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 4s 134ms/step - loss: 3.8615e-04 - mean_absolute_error: 0.0140 - val_loss: 2.2348e-04 - val_mean_absolute_error: 0.0107
# Epoch 10/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step - loss: 4.4260e-04 - mean_absolute_error: 0.0155 - val_loss: 2.0653e-04 - val_mean_absolute_error: 0.0088
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Improved GRU Train RMSE: 1762.36
# Improved GRU Test RMSE: 4575.83
# Improved GRU Train MAE: 1554.78
# Improved GRU Test MAE: 3957.24

# %% [markdown]
# **GRU observations**
#
# Baseline (look_back=10, 8 units, 50 epochs): **Test RMSE 4,733 | MAE 3,248**
#
# Changes made:
# - Wrapped the first GRU layer in `Bidirectional` (64 units → 128 effective outputs).
# - Added a second unidirectional GRU (32 units) to compress the bidirectional features.
# - Used `recurrent_dropout=0.1` and 20% Dropout; `EarlyStopping(patience=10)` also fired quickly.
#
# Improved result: **Test RMSE 4,576 | MAE 3,957** — a small reduction in RMSE but higher MAE, suggesting the model found the overall trend slightly better but made larger individual-step errors. Like the LSTM, the combination of Bidirectional + heavy regularisation caused early stopping to trigger very early, limiting how much the extra capacity could help. The GRU remained the weakest of the three recurrent families on this dataset.

# %% [markdown]
# ### Your summary

# %% [markdown]
# ## Overall summary
#
# ### Actual results
#
# | Model | Test RMSE | Test MAE |
# |---|---|---|
# | **XGBoost (return target)** | **892** | **551** |
# | Improved SimpleRNN | 2,359 | 1,517 |
# | Baseline LSTM | 2,398 | 1,580 |
# | Improved LSTM | 2,499 | 1,662 |
# | Baseline SimpleRNN | 3,953 | 2,410 |
# | Improved GRU | 4,576 | 3,957 |
# | Baseline GRU | 4,733 | 3,248 |
# | XGBoost (raw price target) | 10,491 | 6,341 |
#
# ### What improved performance most
#
# - **Longer look-back (10 → 30 days)** was the biggest lever for the SimpleRNN — it cut test RMSE by ~40%.
# - **EarlyStopping** prevented the baselines' tendency to overfit past epoch 30–40, but also exposed a tension: when combined with heavy regularisation (`recurrent_dropout` + Dropout), it triggered too early for the stacked LSTM and Bidirectional GRU to converge, leaving both *worse* than their baselines.
# - **Target engineering** (XGBoost predicting daily percent-change rather than raw price) was the single highest-impact change in the entire notebook, cutting RMSE from 10,491 to 892 — an order of magnitude better than any recurrent model.
#
# ### Which models were easiest / hardest to tune
#
# - **Improved SimpleRNN** was the clearest win: a straightforward stack + Dropout + longer window improved RMSE 40% with stable training all the way to epoch 80.
# - **Baseline LSTM** remained competitive without any tuning at all (RMSE 2,398), which made it hard to beat with the improved version.
# - **Stacked LSTM and Bidirectional GRU** were the hardest: adding `recurrent_dropout` slowed convergence so much that EarlyStopping fired before the added capacity paid off. Reducing regularisation or increasing patience would likely reverse this.
#
# ### Tradeoffs observed
#
# - **Regularisation vs. convergence speed**: `recurrent_dropout` is a powerful regulariser but slows learning. With `patience=10` the improved LSTM and GRU stopped before recovering, producing worse test metrics than their simpler baselines. This illustrates that regularisation and early stopping must be balanced — tighter patience can eliminate the benefit of deeper architectures.
# - **Model complexity vs. return on investment**: the Bidirectional GRU added substantial compute (≈3× per epoch) for a marginal gain. On a short 1,000-row dataset the added parameters likely hurt more than they helped.
# - **Recurrent models vs. XGBoost**: even the best recurrent model (improved SimpleRNN, RMSE 2,359) is roughly 2.6× worse than the tuned XGBoost (RMSE 892). For tabular time-series forecasting with a moderate look-back, gradient-boosted trees with well-engineered features remain a very strong and much simpler baseline.
# - **Bidirectional caveat**: the Bidirectional wrapper is valid for training/validation (all past data is available), but cannot be used in a true one-step-ahead deployment where future timesteps are unseen — this architectural choice would need to be revisited in a live forecasting system.

# %% [markdown]
# _______________________________________________________________________________________________________________________________
#
# _______________________________________________________________________________________________________________________________

# %% [markdown]
# ### Do you need RNN for time series data?
#
# #### XGB with lagged features

# %% [markdown]
# Plotting function for nonscaled models

# %%
# Generic prediction plotting function for models already on the original scale

def plot_predictions(actual, predicted, title):

    plt.figure(figsize=(10, 4))

    plt.plot(actual, label="Actual")
    plt.plot(predicted, label="Predicted")

    plt.title(title)
    plt.xlabel("Test time index")
    plt.ylabel("Bitcoin Close Price (USD)")

    plt.ticklabel_format(style="plain", axis="y")

    plt.legend()
    plt.show()

# %% [markdown]
# XGB Data preparation

# %%
# Create lagged features for XGBoost

xgb_data = bitcoin[["date"] + features].copy()

lag_days = 10

for lag in range(1, lag_days + 1):
    for col in features:
        xgb_data[f"{col}_lag{lag}"] = xgb_data[col].shift(lag)

xgb_data["target_close_USD"] = xgb_data["close_USD"]

xgb_data = xgb_data.dropna().reset_index(drop=True)

xgb_data.head()
# Out:
#         date  open_USD  high_USD  low_USD  close_USD  volume  open_USD_lag1  \
# 0 2018-05-17   8330.00   8464.00  7979.00    8041.46   25439        8462.00
# 1 2018-05-18   8038.82   8273.21  7911.90    8239.81   23476        8330.00
# 2 2018-05-19   8238.01   8390.80  8095.73    8233.49   17193        8038.82
# 3 2018-05-20   8233.49   8609.00  8163.90    8526.98   19957        8238.01
# 4 2018-05-21   8526.97   8595.31  8305.00    8381.24   21516        8233.49
#
#    high_USD_lag1  low_USD_lag1  close_USD_lag1  ...  high_USD_lag9  \
# 0        8488.00       8083.01         8330.00  ...        9475.70
# 1        8464.00       7979.00         8041.46  ...        9390.00
# 2        8273.21       7911.90         8239.81  ...        9395.12
# 3        8390.80       8095.73         8233.49  ...        9016.80
# 4        8609.00       8163.90         8526.98  ...        8646.88
#
#    low_USD_lag9  close_USD_lag9  volume_lag9  open_USD_lag10  high_USD_lag10  \
# 0       9060.54         9187.56      25533.0         9661.02         9689.67
# 1       8965.00         9310.00      25673.0         9365.00         9475.70
# 2       8970.00         9002.20      25055.0         9178.00         9390.00
# 3       8341.00         8400.00      48227.0         9310.00         9395.12
# 4       8153.00         8465.94      40241.0         9002.21         9016.80
#
#    low_USD_lag10  close_USD_lag10  volume_lag10  target_close_USD
# 0        9181.00          9365.00       33787.0           8041.46
# 1        9060.54          9187.56       25533.0           8239.81
# 2        8965.00          9310.00       25673.0           8233.49
# 3        8970.00          9002.20       25055.0           8526.98
# 4        8341.00          8400.00       48227.0           8381.24
#
# [5 rows x 57 columns]

# %% [markdown]
# XGB train test preparation

# %%
# Prepare XGBoost train/test data

xgb_features = [
    col for col in xgb_data.columns
    if "lag" in col
]

X_xgb = xgb_data[xgb_features]
y_xgb = xgb_data["target_close_USD"]

train_size_xgb = int(len(xgb_data) * 0.8)

trainX_xgb = X_xgb.iloc[:train_size_xgb]
testX_xgb = X_xgb.iloc[train_size_xgb:]

trainY_xgb = y_xgb.iloc[:train_size_xgb]
testY_xgb = y_xgb.iloc[train_size_xgb:]

print("trainX_xgb shape:", trainX_xgb.shape)
print("testX_xgb shape:", testX_xgb.shape)
print("trainY_xgb shape:", trainY_xgb.shape)
print("testY_xgb shape:", testY_xgb.shape)
# Out:
# trainX_xgb shape: (792, 50)
# testX_xgb shape: (198, 50)
# trainY_xgb shape: (792,)
# testY_xgb shape: (198,)

# %% [markdown]
# Build & train model

# %%
# Build and train baseline XGBoost model

from xgboost import XGBRegressor

xgb_model = XGBRegressor(
    n_estimators=100,
    max_depth=3,
    learning_rate=0.1,
    objective="reg:squarederror",
    random_state=42
)

xgb_model.fit(
    trainX_xgb,
    trainY_xgb
)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=3,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=100,
#              n_jobs=None, num_parallel_tree=None, ...)

# %% [markdown]
# Evaluating on test data

# %%
# Evaluate XGBoost baseline on held-out future test data

xgb_test_pred = xgb_model.predict(testX_xgb)

xgb_rmse = np.sqrt(mean_squared_error(testY_xgb, xgb_test_pred))
xgb_mae = mean_absolute_error(testY_xgb, xgb_test_pred)

print(f"Baseline XGBoost Test RMSE: {xgb_rmse:.2f}")
print(f"Baseline XGBoost Test MAE: {xgb_mae:.2f}")
# Out:
# Baseline XGBoost Test RMSE: 10490.81
# Baseline XGBoost Test MAE: 6340.83

# %%
# Visualize baselineXGBoost predictions

plot_predictions(
    testY_xgb.values,
    xgb_test_pred,
    "Baseline XGBoost Test Predictions"
)

# %% [markdown]
# Modifying the XGB target to percent change instead of raw price

# %%
# Improved XGBoost: predict next-day percent change instead of raw price

xgb_return_data = bitcoin[["date"] + features].copy()

xgb_return_data["close_return"] = (
    xgb_return_data["close_USD"]
    .pct_change()
)                                                               # calculate daily percent return

lag_days = 10                                                   # use previous 10 days as predictors

for lag in range(1, lag_days + 1):

    for col in features:
        xgb_return_data[f"{col}_lag{lag}"] = (
            xgb_return_data[col]
            .shift(lag)
        )                                                       # previous feature values become lag predictors

    xgb_return_data[f"close_return_lag{lag}"] = (
        xgb_return_data["close_return"]
        .shift(lag)
    )                                                           # include lagged returns as predictors

xgb_return_data["target_return"] = (
    xgb_return_data["close_return"]
    .shift(-1)
)                                                               # predict next-day return

xgb_return_data["current_close_USD"] = (
    xgb_return_data["close_USD"]
)                                                               # keep current close price for reconstruction later

xgb_return_data = (
    xgb_return_data
    .dropna()
    .reset_index(drop=True)
)                                                               # remove rows without sufficient lag history

xgb_return_features = [
    col for col in xgb_return_data.columns
    if "lag" in col
]                                                               # use lagged values as predictors

X_xgb_return = xgb_return_data[xgb_return_features]
y_xgb_return = xgb_return_data["target_return"]

train_size_xgb_return = int(len(xgb_return_data) * 0.8)        # chronological 80/20 split

trainX_xgb_return = X_xgb_return.iloc[:train_size_xgb_return]
testX_xgb_return = X_xgb_return.iloc[train_size_xgb_return:]

trainY_xgb_return = y_xgb_return.iloc[:train_size_xgb_return]
testY_xgb_return = y_xgb_return.iloc[train_size_xgb_return:]

test_current_close = (
    xgb_return_data["current_close_USD"]
    .iloc[train_size_xgb_return:]
)                                                               # current price used to reconstruct next-day prediction

xgb_return_model = XGBRegressor(
    n_estimators=300,                                           # more trees for stronger learning
    max_depth=2,                                                # shallow trees reduce overfitting
    learning_rate=0.03,                                         # smaller learning steps
    subsample=0.8,                                              # random row sampling
    colsample_bytree=0.8,                                       # random feature sampling
    objective="reg:squarederror",
    random_state=42
)

xgb_return_model.fit(
    trainX_xgb_return,
    trainY_xgb_return
)

xgb_return_pred = xgb_return_model.predict(
    testX_xgb_return
)                                                               # predict next-day percent return

xgb_return_price_pred = (
    test_current_close.values * (1 + xgb_return_pred)
)                                                               # convert predicted return back to predicted price

xgb_return_price_actual = (
    test_current_close.values * (1 + testY_xgb_return.values)
)                                                               # actual next-day price

xgb_return_rmse = np.sqrt(
    mean_squared_error(
        xgb_return_price_actual,
        xgb_return_price_pred
    )
)

xgb_return_mae = mean_absolute_error(
    xgb_return_price_actual,
    xgb_return_price_pred
)

print(f"Improved XGBoost Test RMSE: {xgb_return_rmse:.2f}")
print(f"Improved XGBoost Test MAE: {xgb_return_mae:.2f}")

plot_predictions(
    xgb_return_price_actual,
    xgb_return_price_pred,
    "Improved XGBoost Return-Based Test Predictions"
)
# Out:
# Improved XGBoost Test RMSE: 892.54
# Improved XGBoost Test MAE: 550.68

# %%
# Compare baseline model performance

simple_rnn_rmse, simple_rnn_mae = evaluate_metrics(
    simple_rnn_model,
    testX_bitcoin,
    testY_bitcoin,
    scaler_bitcoin,
    target_index
)

lstm_rmse, lstm_mae = evaluate_metrics(
    lstm_model,
    testX_bitcoin,
    testY_bitcoin,
    scaler_bitcoin,
    target_index
)

gru_rmse, gru_mae = evaluate_metrics(
    gru_model,
    testX_bitcoin,
    testY_bitcoin,
    scaler_bitcoin,
    target_index
)

model_comparison = pd.DataFrame({
    "Model": [
        "SimpleRNN",
        "LSTM",
        "GRU",
        "XGBoost raw price target",
        "XGBoost return target"
    ],

    "RMSE": [
        simple_rnn_rmse,
        lstm_rmse,
        gru_rmse,
        xgb_rmse,
        xgb_return_rmse
    ],

    "MAE": [
        simple_rnn_mae,
        lstm_mae,
        gru_mae,
        xgb_mae,
        xgb_return_mae
    ]
})

model_comparison.sort_values("RMSE")
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
#                       Model          RMSE          MAE
# 4     XGBoost return target    892.536704   550.684864
# 1                      LSTM   2398.134066  1580.108312
# 0                 SimpleRNN   3953.112714  2409.819105
# 2                       GRU   4732.629154  3248.335164
# 3  XGBoost raw price target  10490.806519  6340.832358
